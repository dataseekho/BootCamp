# %% [markdown]
# <a href="https://colab.research.google.com/github/dataseekho/BootCamp/blob/main/dsmp_session_4_git_github_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![_Docs Banner  (2000 x 2000 px) (2).png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-11-03 at 11.24.38.jpeg](data:image/jpeg;base64,...)

# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello1")
# Out:
# Hello1
